# %%
import pandas as pd
import numpy as np

# %%
edited_data = pd.read_csv("data.csv")

# %%
edited_data

# %%
edited_data.info

# %%
edited_data.columns

# %%
len(edited_data)

# %%
edited_data.head()

# %%
edited_data.tail()

# %%
ein=edited_data.head(-2900)
ein
e1 = ein.drop(ein.columns[[ 0]],axis = 1)

# %%
e1.info()

# %%
e1.to_csv("e1.csv")

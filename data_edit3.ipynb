# %%
import pandas as pd
import numpy as np
#edited_data.drop("Unnamed: 0",axis=1,inplace=True)

# %%
edited_data = pd.read_csv("e1.csv")

# %%
edited_data.columns
# Out:
# Index(['Unnamed: 0', '0_1', '0_2', '0_3', '0_4', '0_5', '1_1', '1_2', '1_3',
#        '1_4',
#        ...
#        '28_1', '28_2', '28_3', '28_4', '28_5', '29_1', '29_2', '29_3', '29_4',
#        '29_5'],
#       dtype='object', length=151)

# %%
edited_data.drop("Unnamed: 0",axis=1,inplace=True)

# %%
edited_data.columns
# Out:
# Index(['0_1', '0_2', '0_3', '0_4', '0_5', '1_1', '1_2', '1_3', '1_4', '1_5',
#        ...
#        '28_1', '28_2', '28_3', '28_4', '28_5', '29_1', '29_2', '29_3', '29_4',
#        '29_5'],
#       dtype='object', length=150)

# %%
df_training_data = pd.DataFrame()

# %%
df_testing_data = pd.DataFrame()

# %%
df_train_test_data = pd.DataFrame()

# %%
df_training_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_testing_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_train_test_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df0 = edited_data.iloc[:,0:5]
df1 = edited_data.iloc[:,5:10]
df2 = edited_data.iloc[:,10:15]
df3 = edited_data.iloc[:,15:20]
df4 = edited_data.iloc[:,20:25]
df5 = edited_data.iloc[:,25:30]
df6 = edited_data.iloc[:,30:35]
df7 = edited_data.iloc[:,35:40]
df8 = edited_data.iloc[:,40:45]
df9 = edited_data.iloc[:,45:50]
df10 = edited_data.iloc[:,50:55]
df11 = edited_data.iloc[:,55:60]
df12 = edited_data.iloc[:,60:65]
df13 = edited_data.iloc[:,65:70]
df14 = edited_data.iloc[:,70:75]
df15 = edited_data.iloc[:,75:80]
df16 = edited_data.iloc[:,80:85]
df17 = edited_data.iloc[:,85:90]
df18 = edited_data.iloc[:,90:95]
df19 = edited_data.iloc[:,95:100]
df20 = edited_data.iloc[:,100:105]
df21 = edited_data.iloc[:,105:110]
df22 = edited_data.iloc[:,110:115]
df23 = edited_data.iloc[:,115:120]
df24 = edited_data.iloc[:,120:125]
df25 = edited_data.iloc[:,125:130]
df26 = edited_data.iloc[:,130:135]
df27 = edited_data.iloc[:,135:140]
df28 = edited_data.iloc[:,140:145]
df29 = edited_data.iloc[:,145:150]

# %%
#df = pd.DataFrame( np.concatenate( (df1.values, df2.values), axis=0 ) )

# %%
#df_training_data = pd.concat([df0,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19], ignore_index = True,axis=0)
df_training_data = pd.DataFrame( np.concatenate( (df0,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19), axis=0 ) )

# %%
#df_testing_data  = pd.concat([df20,df21,df22,df23,df24,df25,df26,df27,df28,df29], ignore_index = True,axis=0)
df_testing_data = pd.DataFrame( np.concatenate( (df20,df21,df22,df23,df24,df25,df26,df27,df28,df29), axis=0 ) )

# %%
df_train_test_data = pd.DataFrame( np.concatenate( (df0,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29), axis=0 ) )

# %%
df_training_data
# Out:
#                0         1         2         3              4
# 0     0.22069095  0.993353       0.0       0.0            0.0
# 1     0.18893798  0.913609  0.016241  0.000378   1.5978201f-5
# 2     0.18042353    0.8853  0.028884  0.001575  0.00012306577
# 3     0.14911447  0.938682  0.039463  0.003161  0.00035542675
# 4     0.14910689  0.986508  0.050373  0.004785  0.00082758797
# ...          ...       ...       ...       ...            ...
# 1995     0.00023  0.043129  0.010508  0.222909      0.5039827
# 1996    0.000216  0.041996  0.009693  0.209344     0.45957592
# 1997    0.000193  0.047717  0.009969  0.218951     0.46310937
# 1998    0.000169  0.037029  0.010038  0.219394     0.45172602
# 1999    0.000165  0.037709  0.008058  0.233115     0.48725796
#
# [2000 rows x 5 columns]

# %%
df_testing_data
# Out:
#             0         1         2         3              4
# 0    0.597221  0.588564       0.0       0.0            0.0
# 1    0.525524  0.657575  0.042096  0.001107   3.0699368f-5
# 2    0.488106  0.620875  0.078083  0.004248  0.00021452663
# 3    0.414471  0.651828   0.10831  0.009078   0.0007100994
# 4     0.37092   0.62056  0.133409  0.014673   0.0014287462
# ..        ...       ...       ...       ...            ...
# 995  0.000241  0.084539  0.012024  0.155234     0.49735248
# 996   0.00022  0.087874  0.009916  0.149138      0.5196813
# 997  0.000197  0.087438  0.010282  0.156756      0.5145596
# 998  0.000186  0.076971   0.00857  0.156348     0.57051814
# 999  0.000174  0.079778  0.009136  0.167417     0.54753673
#
# [1000 rows x 5 columns]

# %%
df_train_test_data
# Out:
#                0         1         2         3              4
# 0     0.22069095  0.993353       0.0       0.0            0.0
# 1     0.18893798  0.913609  0.016241  0.000378   1.5978201f-5
# 2     0.18042353    0.8853  0.028884  0.001575  0.00012306577
# 3     0.14911447  0.938682  0.039463  0.003161  0.00035542675
# 4     0.14910689  0.986508  0.050373  0.004785  0.00082758797
# ...          ...       ...       ...       ...            ...
# 2995    0.000241  0.084539  0.012024  0.155234     0.49735248
# 2996     0.00022  0.087874  0.009916  0.149138      0.5196813
# 2997    0.000197  0.087438  0.010282  0.156756      0.5145596
# 2998    0.000186  0.076971   0.00857  0.156348     0.57051814
# 2999    0.000174  0.079778  0.009136  0.167417     0.54753673
#
# [3000 rows x 5 columns]

# %%
df_training_data.rename(columns = {0:'A', 1:'B', 2:'C', 3:'D', 4:'E'}, inplace = True)
df_training_data

# %%
df_testing_data.rename(columns = {0:'A', 1:'B', 2:'C', 3:'D', 4:'E'}, inplace = True)
df_testing_data

# %%
df_train_test_data.rename(columns = {0:'A', 1:'B', 2:'C', 3:'D', 4:'E'}, inplace = True)
df_train_test_data

# %%
df_training_data.to_csv("df_training_data.csv")
df_testing_data.to_csv("df_testing_data.csv")
df_train_test_data.to_csv("df_train_test_data.csv")
